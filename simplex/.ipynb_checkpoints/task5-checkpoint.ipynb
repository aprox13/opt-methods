# %%
from IPython.display import Image

# %% [markdown]
# ## Дана функция и ограничения.
#
# Решить графическим методом

# %%
Image(filename='img/task5.png')

# %% [markdown]
# Построим область решений
